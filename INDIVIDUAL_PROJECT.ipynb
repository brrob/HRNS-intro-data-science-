# %% [markdown]
# # INDIVIDUAL PROJECT
#
# In this final project, you will focus on exploratory data analysis of stock prices. Keep in mind, this project is just meant to practice your visualization and pandas skills, it is not meant to be a robust financial analysis or be taken as financial advice
#
# ------
# You will focus on bank stocks and see how they progressed throughout the [ financial crisis](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) all the way to November 20th, 2023.

# %% [markdown]
# # Get The Data
# In this section, you will learn how to use pandas to directly read from Yahoo finance.
# First, you will need to install pandas_datareader (**pip install yfinance**), which will allow to to [read stock information directly from the internet](https://finance.yahoo.com/u/yahoo-finance/watchlists/bank-and-financial-services-stocks/)

# %% [markdown]
# # Import Library
# The Necesary Libraries have been imported for you already

# %%
# Import the Necessary Libraries

import pandas as pd 
import numpy as np 
import datetime as dt
# %matplotlib inline

# %%
# You may need to install Yahoo Finance first
# !pip install yfinance
# Out:
# Collecting yfinance
#   Obtaining dependency information for yfinance from https://files.pythonhosted.org/packages/1c/19/bf19123baf16a55fd38cbb100b5a49380b9b6db7279987034689d11254c7/yfinance-0.2.32-py2.py3-none-any.whl.metadata
#   Downloading yfinance-0.2.32-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pandas>=1.3.0 in /Users/brobillard/anaconda3/lib/python3.11/site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in /Users/brobillard/anaconda3/lib/python3.11/site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in /Users/brobillard/anaconda3/lib/python3.11/site-packages (from yfinance) (2.31.0)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: lxml>=4.9.1 in /Users/brobillard/anaconda3/lib/python3.11/site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/brobillard/anaconda3/lib/python3.11/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /Users/brobillard/anaconda3/lib/python3.11/site-packages (from yfinance) (2022.7)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Obtaining dependency information for frozendict>=2.3.4 from https://files.pythonhosted.org/packages/24/41/e53837badf8c85bf07ca1ea735cdd78df0f5bfe59e3affaaa174a55522c4/frozendict-2.3.9-py3-none-any.whl.metadata
#   Downloading frozendict-2.3.9-py3-none-any.whl.metadata (20 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.0.tar.gz (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 12.3 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/brobillard/anaconda3/lib/python3.11/site-packages (from yfinance) (4.12.2)
# Collecting html5lib>=1.1 (from yfinance)
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /Users/brobillard/anaconda3/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in /Users/brobillard/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Users/brobillard/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/brobillard/anaconda3/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/brobillard/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/brobillard/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/brobillard/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/brobillard/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2023.7.22)
# Downloading yfinance-0.2.32-py2.py3-none-any.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 7.4 MB/s eta 0:00:00
# Downloading frozendict-2.3.9-py3-none-any.whl (14 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml) ... done
#   Created wheel for peewee: filename=peewee-3.17.0-py3-none-any.whl size=135721 sha256=754d35a44c583320ad5476f98a9280edefcd730d81567fcd2529a01c48f8e00e
#   Stored in directory: /Users/brobillard/Library/Caches/pip/wheels/02/20/23/74a10d0cd31f5d41c19b92ddf4c138ceff01b9f4675f19dbf5
# Successfully built peewee
# Installing collected packages: peewee, multitasking, html5lib, frozendict, yfinance
# Successfully installed frozendict-2.3.9 html5lib-1.1 multitasking-0.0.11 peewee-3.17.0 yfinance-0.2.32

# %% [markdown]
# # Data
# You need to get data using yahoo finance. You will get stock information for the following:
# * Bank Of America
# * Amazon
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# ** Find the stock data from Jan 1st, 2006 to Novemebr 20 th 2023 for each of these banks.
#
# I. First, set each bank to be a separat dataframe, with the variable name for that bank being its ticker symbol. And then combine them using the concat method.
#
# II. Second, find the stock data altogether
#
# This will involve few steps

# %% [markdown]
# ### I. Setting the stock data for each bank separately and then combine
# * then as one single dataframe using pd.concat

# %%
# Step 1 import yfinance as yf

import yfinance as yf

# %%
# Step 2: Set the start and the end as follow:
start = dt.datetime (2006,1,1)
end = dt.datetime (2023,11,20)

# %%
#Step 3:
#For the Signature Bank stock, you use yahoo finance (yf) and 
# the ticker name symbol "SBNY" for Signature Bank
SBNY = yf.download('SBNY', start, end)

# For the Silicon Valey Bank
SIVBQ = yf.download('SIVBQ', start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# Step 4: set the tickers, using the stiker symbol for each Bank
tickers = ['SBNY','SIVBQ']

# %% [markdown]
# * Now, use pd.concat to concatenate the Banks DataFrames together
#     to a single data frame called stock_df

# %%
# Step 5: Use pandas to combine these two data as one dataframe
stock_df = pd.concat([SBNY,SIVBQ], axis=1, keys=tickers)

# %%
# Setp 6: Check the first five row of these data
stock_df.head()
# Out:
#                  SBNY                                                      \
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2006-01-03  28.090000  28.620001  27.900000  28.500000  26.421671  377593
# 2006-01-04  28.450001  28.719999  28.290001  28.500000  26.421671  314188
# 2006-01-05  28.299999  28.500000  28.299999  28.400000  26.328962   48196
# 2006-01-06  28.650000  28.790001  28.150000  28.590000  26.505106   90469
# 2006-01-09  28.700001  28.820000  28.469999  28.799999  26.699793   87657
#
#                 SIVBQ
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2006-01-03  47.270000  47.340000  45.849998  46.549999  46.549999   519084.0
# 2006-01-04  46.330002  46.770000  45.950001  46.130001  46.130001  1026640.0
# 2006-01-05  46.000000  46.400002  45.680000  45.700001  45.700001   581344.0
# 2006-01-06  45.700001  46.810001  45.700001  46.700001  46.700001   762263.0
# 2006-01-09  46.570000  46.799999  46.419998  46.669998  46.669998   456720.0

# %%
# You can plot individual stock. What can you say about 
# the Signature Bank?

import seaborn as sns
SBNY['Open'].plot()
sns.despine()

# %% [markdown]
#  # Task 1
#  * ## Mimic step 1 through step 6
#
#  to access the stock data of
#  * Amazon
# * Bank Of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
#
# from Jan 1st, 2006 to Novemebr 15th 2023 for each of these banks.
# Set each bank to be a separat dataframe, with the variable name for that bank being its ticker symbol. You find the ticker symbol for each Company. Use pandas to combine as a single dataframe, called stocks_df

# %%
# Amazon
AMZN = yf.download('AMZN', start='2006-01-1', end='2023-11-15')
# Bank of America
BAC = yf.download('BAC', start='2006-01-1', end='2023-11-15')
# JPMorgan Chase
JPM = yf.download('JPM',start='2006-01-1', end='2023-11-15')
# City Group
C = yf.download('C',start='2006-01-1', end='2023-11-15')
# Goldman Sachs
GS = yf.download('GS',start='2006-01-1', end='2023-11-15')
# Morgan Stanley
MS = yf.download('MS',start='2006-01-1', end='2023-11-15')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# Create a list of tickers for thes stocks and call it tickers
tickers = ['AMZN','BAC','JPM','C','GS','MS']

# %%
#use set_option to display all 36 columns of the stocks_df
pd.set_option('display.max_columns', 36)

# %%
stock_df = pd.concat([AMZN,BAC,C,GS,JPM,MS],axis=1,keys=tickers)
stock_df.columns.names = ['Bank Ticker','Stock Info']

# %%
# Check the first five rows of the stocks_df
stock_df.head()
# Out:
# Bank Ticker    AMZN                                                     BAC  \
# Stock Info     Open    High     Low   Close Adj Close     Volume       Open
# Date
# 2006-01-03   2.3735  2.3925  2.3125  2.3790    2.3790  151644000  46.919998
# 2006-01-04   2.3745  2.3865  2.3345  2.3625    2.3625  148818000  47.000000
# 2006-01-05   2.3580  2.4100  2.3555  2.3825    2.3825  108344000  46.580002
# 2006-01-06   2.3985  2.4290  2.3660  2.3935    2.3935  123058000  46.799999
# 2006-01-09   2.3275  2.3550  2.3200  2.3540    2.3540  178862000  46.720001
#
# Bank Ticker                                                               JPM  \
# Stock Info        High        Low      Close  Adj Close    Volume        Open
# Date
# 2006-01-03   47.180000  46.150002  47.080002  32.168697  16296700  490.000000
# 2006-01-04   47.240002  46.450001  46.580002  31.827047  17757900  488.600006
# 2006-01-05   46.830002  46.320000  46.639999  31.868052  14970700  484.399994
# 2006-01-06   46.910000  46.349998  46.570000  31.820229  12599800  488.799988
# 2006-01-09   46.970001  46.360001  46.599998  31.840725  15619400  486.000000
#
# Bank Ticker                                                           \
# Stock Info         High         Low       Close   Adj Close   Volume
# Date
# 2006-01-03   493.799988  481.100006  492.899994  338.403168  1537600
# 2006-01-04   491.000000  483.500000  483.799988  332.155518  1870960
# 2006-01-05   487.799988  484.000000  486.200012  333.803375  1143160
# 2006-01-06   489.000000  482.000000  486.200012  333.803375  1370210
# 2006-01-09   487.399994  483.000000  483.899994  332.224182  1680740
#
# Bank Ticker           C                                                 \
# Stock Info         Open        High         Low       Close  Adj Close
# Date
# 2006-01-03   126.699997  129.440002  124.230003  128.869995  98.085472
# 2006-01-04   127.349998  128.910004  126.379997  127.089996  96.730675
# 2006-01-05   126.000000  127.320000  125.610001  127.040001  96.692619
# 2006-01-06   127.290001  129.250000  127.290001  128.839996  98.062660
# 2006-01-09   128.500000  130.619995  128.000000  130.389999  99.242401
#
# Bank Ticker                  GS                                              \
# Stock Info    Volume       Open       High        Low      Close  Adj Close
# Date
# 2006-01-03   6188700  39.830002  40.360001  39.299999  40.189999  24.948782
# 2006-01-04   4861600  39.779999  40.139999  39.419998  39.619999  24.804783
# 2006-01-05   3717400  39.610001  39.810001  39.500000  39.740002  24.879908
# 2006-01-06   4319600  39.919998  40.240002  39.549999  40.020000  25.055208
# 2006-01-09   4723500  39.880001  40.720001  39.880001  40.669998  25.462152
#
# Bank Ticker                   MS                                              \
# Stock Info     Volume       Open       High        Low      Close  Adj Close
# Date
# 2006-01-03   12838600  57.169998  58.490002  56.740002  58.310001  33.585445
# 2006-01-04   13491500  58.700001  59.279999  58.349998  58.349998  33.608494
# 2006-01-05    8109400  58.549999  58.590000  58.020000  58.509998  33.700653
# 2006-01-06    7966900  58.770000  58.849998  58.049999  58.570000  33.735218
# 2006-01-09   16575200  58.630001  59.290001  58.619999  59.189999  34.092319
#
# Bank Ticker
# Stock Info    Volume
# Date
# 2006-01-03   5377000
# 2006-01-04   7977800
# 2006-01-05   5778000
# 2006-01-06   6889800
# 2006-01-09   4144500

# %%
# Part II. Access all stocks once and call that dataframe stocks.

# For example: to access Signature Bank and Silcon Valey Bank data,
# we use
stock_df = yf.download(['SBNY','SIVBQ'],start, end)
# Out:
# [*********************100%%**********************]  2 of 2 completed

# %%
# Check the first five rows of the dataframe
stock_df.head()
# Out:
#             Adj Close                 Close                  High             \
#                  SBNY      SIVBQ       SBNY      SIVBQ       SBNY      SIVBQ
# Date
# 2006-01-03  26.421669  46.549999  28.500000  46.549999  28.620001  47.340000
# 2006-01-04  26.421669  46.130001  28.500000  46.130001  28.719999  46.770000
# 2006-01-05  26.328964  45.700001  28.400000  45.700001  28.500000  46.400002
# 2006-01-06  26.505108  46.700001  28.590000  46.700001  28.790001  46.810001
# 2006-01-09  26.699789  46.669998  28.799999  46.669998  28.820000  46.799999
#
#                   Low                  Open             Volume
#                  SBNY      SIVBQ       SBNY      SIVBQ    SBNY      SIVBQ
# Date
# 2006-01-03  27.900000  45.849998  28.090000  47.270000  377593   519084.0
# 2006-01-04  28.290001  45.950001  28.450001  46.330002  314188  1026640.0
# 2006-01-05  28.299999  45.680000  28.299999  46.000000   48196   581344.0
# 2006-01-06  28.150000  45.700001  28.650000  45.700001   90469   762263.0
# 2006-01-09  28.469999  46.419998  28.700001  46.570000   87657   456720.0

# %% [markdown]
#  Do the same thing using the
#  to access the stock data of
# * Bank Of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# and call that dataframe "stocks"

# %%
# Your code here
stocks = yf.download(['AMZN','BAC','JPM','C','GS','MS'],start='2006-01-1', end='2023-11-15')
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
stocks.head()
# Out:
#            Adj Close                                                          \
#                 AMZN        BAC           C         GS        JPM         MS
# Date
# 2006-01-03    2.3790  32.168697  338.403168  98.085472  24.948782  33.585445
# 2006-01-04    2.3625  31.827047  332.155518  96.730675  24.804783  33.608494
# 2006-01-05    2.3825  31.868052  333.803375  96.692619  24.879908  33.700653
# 2006-01-06    2.3935  31.820229  333.803375  98.062660  25.055208  33.735218
# 2006-01-09    2.3540  31.840725  332.224182  99.242401  25.462152  34.092319
#
#              Close                                                           \
#               AMZN        BAC           C          GS        JPM         MS
# Date
# 2006-01-03  2.3790  47.080002  492.899994  128.869995  40.189999  58.310001
# 2006-01-04  2.3625  46.580002  483.799988  127.089996  39.619999  58.349998
# 2006-01-05  2.3825  46.639999  486.200012  127.040001  39.740002  58.509998
# 2006-01-06  2.3935  46.570000  486.200012  128.839996  40.020000  58.570000
# 2006-01-09  2.3540  46.599998  483.899994  130.389999  40.669998  59.189999
#
#               High                                                           \
#               AMZN        BAC           C          GS        JPM         MS
# Date
# 2006-01-03  2.3925  47.180000  493.799988  129.440002  40.360001  58.490002
# 2006-01-04  2.3865  47.240002  491.000000  128.910004  40.139999  59.279999
# 2006-01-05  2.4100  46.830002  487.799988  127.320000  39.810001  58.590000
# 2006-01-06  2.4290  46.910000  489.000000  129.250000  40.240002  58.849998
# 2006-01-09  2.3550  46.970001  487.399994  130.619995  40.720001  59.290001
#
#                Low                                                           \
#               AMZN        BAC           C          GS        JPM         MS
# Date
# 2023-11-08    44521700  31896000  14761600  1484400   7618200   8075200
# 2023-11-09    36235400  32267900  19128400  1787900   7992500   9497200
# 2023-11-10    49287800  32858500  11912500  1781400   7983300   8924000
# 2023-11-13    35680600  28521800  16332100  1403300   6676300   4868400
# 2023-11-14    56674600  66676300  26218500  3592700   9927700  12287700
#
# [4498 rows x 36 columns]

# %% [markdown]
# # Task 2
#  * # EDA
# Let's explore the data a bit!

# %%
# What is the maximum Close Price for each Stock?
#(Hint use the stocks dataframe)
# Your code here
stocks['Close'].max()
# Out:
# Stock Info
# AMZN    186.570496
# BAC      54.900002
# C       564.099976
# GS      423.850006
# JPM     171.779999
# MS      108.730003
# dtype: float64

# %%
# Out:
# Stock Info
# AMZN    186.570496
# BAC      54.900002
# C       564.099976
# GS      423.850006
# JPM     171.779999
# MS      108.730003
# dtype: float64

# %% [markdown]
#  Create a new empty DataFrame called returns. This dataframe
# will contain the returns for each stock. Returns are obtained by
# $$r_t=\frac{p_t-p_{t-1}}{p_{t-1}}=\frac{p_t}{p_{t-1}}-1$$

# %%
returns = pd.DataFrame()

# %% [markdown]
#  Use pandas pct_change() method on the Close column to create a column
#  representing this return value and store that result to the returns.

# %%
returns = stocks['Close'].pct_change()

# %%
# Check the first five rows of the returns
returns.head()
# Out:
# Stock Info      AMZN       BAC         C        GS       JPM        MS
# Date
# 2006-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2006-01-04 -0.006936 -0.010620 -0.018462 -0.013812 -0.014183  0.000686
# 2006-01-05  0.008466  0.001288  0.004961 -0.000393  0.003029  0.002742
# 2006-01-06  0.004617 -0.001501  0.000000  0.014169  0.007046  0.001025
# 2006-01-09 -0.016503  0.000644 -0.004731  0.012030  0.016242  0.010586

# %% [markdown]
# Using this returns DataFrame, figure out what dates each bank stock had the best and worst single day returns.You should notice that 3 of the banks have the same worst drop, did anything significant happen that day? Keep inmind that you are returning the index (date) and not the actual stock return value.

# %%
returns.idxmin()
# Out:
# Stock Info
# AMZN   2006-07-26
# BAC    2009-01-20
# C      2009-02-27
# GS     2009-01-20
# JPM    2009-01-20
# MS     2008-10-09
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# Stock Info
# AMZN   2007-04-25
# BAC    2009-04-09
# C      2008-11-24
# GS     2008-11-24
# JPM    2009-01-21
# MS     2008-10-13
# dtype: datetime64[ns]

# %% [markdown]
# * # VISUALIZATION

# %%
# Graph the Close column for each stock in the stocks dataframe 
# that you've created. Is there any relationship between this plot 
# and the worst drop date of these stocks?
#your code here

# %%
stocks['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Create a pairplot using seaborn of the returns dataframe. What stock stands out to you? Why?

# %%
#Your code here

# %%
sns.pairplot(returns)

# %%
# Do histogram plot, for each of these stocks.
# Your code here

# %%
stocks['Close'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Moving Average

# %% [markdown]
# Plot the 30-day moving averages for JPM CHASE and Morgan Stanley stocks for the first 600 days. Use will need to use the individual daframe that you have create for each stock in Part I.

# %%
# Your code here

# %%
JPM[ 'Close'].rolling(window=30).mean ().iloc[0:599].plot ()
JPM['Close'].iloc[0:599].plot()
MS[ 'Close'].rolling(window=30).mean().iloc[0:599].plot()
MS[ 'Close'].iloc[0:599].plot ()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Excellent Job!
